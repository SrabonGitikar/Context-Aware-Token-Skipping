# %% [markdown]
# First, we need to set up the environment with the necessary Hugging Face libraries, including bitsandbytes for memory-efficient model loading and llmlingua for the base token importance.

# %%
# !pip install -q transformers datasets accelerate bitsandbytes torch
# !pip install -q llmlingua
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 11.7 MB/s eta 0:00:00

# %% [markdown]
# We will load the TweetEval dataset, the RoBERTa classifier, and the Qwen2.5 generator.

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModelForSequenceClassification, BitsAndBytesConfig
from datasets import load_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"

# 1. Load Dataset (TweetEval - Irony)
print("Loading Dataset...")
dataset = load_dataset("tweet_eval", "irony")
test_data = dataset['test']

# 2. Load Evaluation Classifier (RoBERTa)
print("Loading RoBERTa Classifier...")
roberta_name = "cardiffnlp/twitter-roberta-base-irony"
rob_tokenizer = AutoTokenizer.from_pretrained(roberta_name)
rob_model = AutoModelForSequenceClassification.from_pretrained(roberta_name).to(device)

# 3. Define the 4-bit Quantization Configuration
print("Configuring 4-bit Quantization...")
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16 # Speeds up computation on T4
)

# 4. Load Reasoning Generator (Qwen 3B with updated quantization)
print("Loading Qwen2.5-3B...")
qwen_name = "Qwen/Qwen2.5-3B-Instruct"
qwen_tokenizer = AutoTokenizer.from_pretrained(qwen_name)
qwen_model = AutoModelForCausalLM.from_pretrained(
    qwen_name,
    device_map="auto",
    quantization_config=bnb_config
)
# Out:
# Loading Dataset...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# irony/train-00000-of-00001.parquet:   0%|          | 0.00/183k [00:00<?, ?B/s]
# irony/test-00000-of-00001.parquet:   0%|          | 0.00/54.0k [00:00<?, ?B/s]
# irony/validation-00000-of-00001.parquet:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2862 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/784 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/955 [00:00<?, ? examples/s]
# Loading RoBERTa Classifier...
# config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-irony
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Configuring 4-bit Quantization...
# Loading Qwen2.5-3B...
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %% [markdown]
# This cell translates our equation for $H(c)$ and the scaled sigmoid transformation into code. It extracts the logits from Qwen's generation to calculate how "uncertain" or complex the reasoning is.

# %%
import torch
import torch.nn.functional as F
import math

def calculate_dynamic_gamma(logits, min_gamma=0.1, max_gamma=0.9, k=1.0, mu=0.5):
    """
    Calculates the reasoning entropy and maps it to a dynamic compression ratio.
    """
    # Convert logits to probabilities
    probs = F.softmax(logits, dim=-1)

    # Epsilon (1e-9) to prevent log(0) yielding -inf and breaking the sum into a nan
    epsilon = 1e-9
    entropy_tensor = -torch.sum(probs * torch.log(probs + epsilon), dim=-1)
    entropy = entropy_tensor.mean().item()

    # Fallback catch just in case a nan slips through due to precision limits
    if math.isnan(entropy):
        entropy = 0.0

    # USING math.exp instead of np.exp since entropy is a standard float here
    gamma_dyn = min_gamma + (max_gamma - min_gamma) / (1 + math.exp(-k * (entropy - mu)))

    return gamma_dyn, entropy

# %% [markdown]
# This is the core of the adversarial robustness. We pass the text through RoBERTa, grab the embeddings, and compute the gradient of the loss with respect to those embeddings.

# %%
def get_gradient_sensitivity(text, rob_tokenizer, rob_model, device, target_class=1):
    """
    Approximates token impact by checking the gradient norm of the embeddings
    during a backward pass in the RoBERTa classifier.
    """
    inputs = rob_tokenizer(text, return_tensors="pt").to(device)

    # Get the embedding layer output and retain its gradients
    embeddings = rob_model.roberta.embeddings.word_embeddings(inputs['input_ids'])
    embeddings.retain_grad()

    # Forward pass
    outputs = rob_model(inputs_embeds=embeddings, attention_mask=inputs['attention_mask'])
    logits = outputs.logits

    # Compute a dummy loss against the predicted or target class
    loss = F.cross_entropy(logits, torch.tensor([target_class]).to(device))

    # Backward pass to get gradients
    rob_model.zero_grad()
    loss.backward()

    # Calculate the L2 norm of the gradients for each token
    grad_norms = embeddings.grad.norm(dim=-1).squeeze().cpu().numpy()

    # Map back to tokens
    tokens = rob_tokenizer.convert_ids_to_tokens(inputs['input_ids'].squeeze())

    # Explicit list of tokens and punctuation to completely ignore
    skip_tokens = {'<s>', '</s>', '<pad>', '<unk>', '.', ',', ':', '"', "'", '?', '!'}

    sensitivity_scores = {}
    for token, grad in zip(tokens, grad_norms):
        # Clean special characters from RoBERTa tokens (like Ġ)
        clean_token = token.replace('Ġ', '').strip()

        # Filtering logic to ignore special tokens and single-character noise
        if clean_token and token not in skip_tokens and len(clean_token) > 1:
            # If a word is split into subwords, keep the max gradient value
            if clean_token in sensitivity_scores:
                sensitivity_scores[clean_token] = max(sensitivity_scores[clean_token], float(grad))
            else:
                sensitivity_scores[clean_token] = float(grad)

    return sensitivity_scores

# %% [markdown]
# Ablation

# %%
import torch
import torch.nn.functional as F
import nltk, re
from nltk.corpus import stopwords

nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)

def classify_tweet(tweet_text, rob_tokenizer, rob_model, device):
    """Classify the raw tweet and return (predicted_class, logits_tensor)."""
    inputs = rob_tokenizer(tweet_text, return_tensors="pt",
                           truncation=True, max_length=128).to(device)
    with torch.no_grad():
        outputs = rob_model(**inputs)
    logits = outputs.logits
    prediction = torch.argmax(logits, dim=-1).item()
    return prediction, logits


# ─────────────────────────────────────────────────────────────────────────────
# ROOT CAUSE FIX: The old keyword scanner gave cot_signal=1.0 for almost every
# tweet because Qwen uses words like "ironic" and "sarcasm" even when describing
# WHY something is NOT ironic. This made the CoT signal useless.
#
# NEW APPROACH: Parse only the VERDICT LINE that Qwen is prompted to output at
# the end of its reasoning ("Verdict: IRONIC" / "Verdict: NON-IRONIC").
# This is a hard 0/1 signal from Qwen's actual conclusion, not its vocabulary.
#
# Fallback: if the verdict line is missing, scan only the FINAL 2 SENTENCES
# (the conclusion), not the full CoT body where analytical vocabulary pollutes.
# ─────────────────────────────────────────────────────────────────────────────
def extract_structured_cot_signal(cot_text):
    """
    Returns a float in {0.0, 0.5, 1.0}:
      1.0 → Qwen explicitly concluded IRONIC
      0.0 → Qwen explicitly concluded NON-IRONIC
      0.5 → No clear verdict found (neutral / abstain)
    """
    lower = cot_text.lower()

    # Priority 1: explicit verdict line
    verdict_match = re.search(
        r"verdict\s*[:\-]\s*(ironic|non[- ]?ironic|not ironic|sarcastic|not sarcastic)",
        lower
    )
    if verdict_match:
        v = verdict_match.group(1)
        if "non" in v or "not" in v:
            return 0.0
        else:
            return 1.0

    # Priority 2: scan only the final 2 sentences
    sentences = re.split(r"(?<=[.!?])\s+", cot_text.strip())
    conclusion = " ".join(sentences[-2:]).lower() if len(sentences) >= 2 else lower

    CONCLUDE_IRONIC   = {"is ironic", "is sarcastic", "contains irony",
                         "irony is present", "this is ironic", "therefore ironic",
                         "tweet is ironic", "concludes ironic"}
    CONCLUDE_NONIRONIC = {"is not ironic", "is not sarcastic", "no irony",
                          "not ironic", "non-ironic", "sincere", "literal statement",
                          "therefore not", "no sarcasm", "not sarcastic"}

    ironic_hits    = sum(1 for p in CONCLUDE_IRONIC    if p in conclusion)
    nonironic_hits = sum(1 for p in CONCLUDE_NONIRONIC if p in conclusion)

    if ironic_hits > nonironic_hits:    return 1.0
    if nonironic_hits > ironic_hits:    return 0.0
    return 0.5   # genuinely ambiguous conclusion


# ─────────────────────────────────────────────────────────────────────────────
# entropy_to_alpha  — the entropy-gated adaptive fusion weight
# KEY INSIGHT (from ablation analysis):
#   ENTROPY_ONLY outperforms FULL_RDS because the CoT signal was too noisy.
#   But entropy itself IS informative:
#     Low H(c)  → Qwen generated confidently → its verdict is more trustworthy
#                 → reduce alpha (give CoT more weight)
#     High H(c) → Qwen was uncertain during generation → verdict less reliable
#                 → raise alpha (lean on RoBERTa more)
# This replaces the fixed alpha=0.7 with a function of entropy.
# ─────────────────────────────────────────────────────────────────────────────
def entropy_to_alpha(entropy,
                     low_thresh=0.2, high_thresh=0.5,
                     alpha_low=0.55,  alpha_high=0.85):
    """
    Maps reasoning entropy to a RoBERTa weight (alpha).
      entropy <= low_thresh  → alpha = alpha_low  (trust CoT more)
      entropy >= high_thresh → alpha = alpha_high (trust RoBERTa more)
      in between             → linear interpolation
    """
    if entropy <= low_thresh:
        return alpha_low
    elif entropy >= high_thresh:
        return alpha_high
    else:
        t = (entropy - low_thresh) / (high_thresh - low_thresh)
        return alpha_low + t * (alpha_high - alpha_low)


# ─────────────────────────────────────────────────────────────────────────────
# fused_classify_v2  — the improved decision function

# Formula:
#   alpha = entropy_to_alpha(H(c))       ← dynamic, not fixed
#   p_final = alpha * p_RoBERTa + (1-alpha) * p_CoT_verdict
# ─────────────────────────────────────────────────────────────────────────────
def fused_classify_v2(tweet_text, cot_text, entropy,
                      rob_tokenizer, rob_model, device):
    """
    Entropy-gated fusion of RoBERTa tweet probability and Qwen verdict signal.
    Returns: (prediction, roberta_prob, cot_signal, alpha, fused_prob)
    """
    # RoBERTa on the original tweet
    _, tweet_logits = classify_tweet(tweet_text, rob_tokenizer, rob_model, device)
    tweet_probs = F.softmax(tweet_logits, dim=-1).squeeze().cpu()
    p_roberta = tweet_probs[1].item()   # P(ironic) from RoBERTa

    # Qwen structured verdict
    cot_signal = extract_structured_cot_signal(cot_text)

    # Entropy-adaptive alpha
    alpha = entropy_to_alpha(entropy)

    # Weighted fusion
    p_fused = alpha * p_roberta + (1 - alpha) * cot_signal
    prediction = int(p_fused >= 0.5)

    return prediction, p_roberta, cot_signal, alpha, p_fused


# ─────────────────────────────────────────────────────────────────────────────
# improved compress_cot  (contrastive connectors preserved)
# ─────────────────────────────────────────────────────────────────────────────
CONTRASTIVE_CONNECTORS = {
    "but", "yet", "though", "although", "however", "despite", "while",
    "whereas", "still", "even", "never", "not", "no", "without", "barely"
}

def compress_cot_improved(original_text, gamma_dyn, critical_tokens):
    stop_words = set(stopwords.words("english")) - CONTRASTIVE_CONNECTORS
    words = original_text.split()
    target_length = max(5, int(len(words) * (1.0 - gamma_dyn)))
    scored_words = []
    for idx, word in enumerate(words):
        clean = word.lower().strip(".,!?\"'")
        is_critical = any(crit.lower() in clean for crit in critical_tokens if len(crit) >= 4)
        if is_critical:                              score = 1000
        elif clean in CONTRASTIVE_CONNECTORS:        score = 500
        elif clean not in stop_words and len(clean) >= 3: score = 10
        else:                                        score = 1
        scored_words.append((idx, word, score))
    scored_words.sort(key=lambda x: x[2], reverse=True)
    kept = sorted(scored_words[:target_length], key=lambda x: x[0])
    return " ".join(w[1] for w in kept)

print("✅ All upgraded helper functions loaded.")
print("   • extract_structured_cot_signal  — verdict-line parser (fixes noisy CoT signal)")
print("   • entropy_to_alpha               — entropy-gated adaptive fusion weight")
print("   • fused_classify_v2              — improved decision function")
# Out:
# ✅ All upgraded helper functions loaded.
#    • extract_structured_cot_signal  — verdict-line parser (fixes noisy CoT signal)
#    • entropy_to_alpha               — entropy-gated adaptive fusion weight
#    • fused_classify_v2              — improved decision function

# %% [markdown]
# This cell loops through a few test examples. It prompts Qwen for a Chain-of-Thought, calculates the dynamic budget, extracts the gradient sensitivities, and prepares the data for the final fusion.

# %%
import torch
import pandas as pd
from IPython.display import display

# ─────────────────────────────────────────────────────────────────────────────
# IMPROVED MAIN PIPELINE  —  RDS v2
#
# Three targeted upgrades over the previous version:
#
#   [1] Structured CoT verdict prompt
#       Qwen is now asked to end its reasoning with an explicit "Verdict: IRONIC"
#       or "Verdict: NON-IRONIC" line. This replaces the noisy keyword scan that
#       was returning signal=1.0 for almost every tweet.
#
#   [2] Entropy-gated adaptive alpha
#       Alpha is no longer fixed at 0.7. Low entropy (confident Qwen) → lower
#       alpha (trust Qwen more). High entropy (uncertain Qwen) → higher alpha
#       (trust RoBERTa more). Derived from the ablation study showing
#       ENTROPY_ONLY beat FULL_RDS because the CoT signal was corrupted.
#
#   [3] Fusion on p_ironic directly
#       No change to the fusion arithmetic — just cleaner inputs.
# ─────────────────────────────────────────────────────────────────────────────

STRUCTURED_PROMPT = (
    "Analyze whether the following tweet is ironic or non-ironic. "
    "Think step-by-step, then end your response with EXACTLY one of:\n"
    "Verdict: IRONIC\n"
    "Verdict: NON-IRONIC\n\n"
    "Tweet: \'{tweet}\'"
)

# CHANGED: Added 'tweet_num' as an optional parameter
def generate_cot_and_analyze_v2(tweet, mode="FULL_RDS", tweet_num=""):
    # CHANGED: Formatted the print statement to include the tweet number if provided
    num_str = f" {tweet_num}" if tweet_num else ""
    print(f"\n--- Processing Tweet{num_str}: {tweet[:60]}... ---")

    # ── Step 1: Generate CoT with structured verdict prompt ───────────────
    prompt = STRUCTURED_PROMPT.format(tweet=tweet)
    inputs = qwen_tokenizer(prompt, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = qwen_model.generate(
            **inputs,
            max_new_tokens=120,          # slightly more to allow verdict line
            return_dict_in_generate=True,
            output_scores=True
        )

    generated_ids = outputs.sequences[0][inputs["input_ids"].shape[1]:]
    cot_text = qwen_tokenizer.decode(generated_ids, skip_special_tokens=True)
    print(f"  CoT Length : {len(cot_text.split())} words")

    # ── Step 2: Global Budgeter (Entropy → Dynamic Gamma) ─────────────────
    if mode in ["FULL_RDS", "ENTROPY_ONLY"]:
        logits_stack = torch.stack(outputs.scores, dim=1).squeeze(0)
        gamma_dyn, entropy = calculate_dynamic_gamma(logits_stack)
        print(f"  Entropy    : {entropy:.3f}  →  Gamma: {gamma_dyn:.3f}")
    else:
        gamma_dyn, entropy = 0.5, 0.0

    # ── Step 3: Local Guardian (Gradient Sensitivity) ─────────────────────
    if mode in ["FULL_RDS", "GRADIENT_ONLY"]:
        sensitivities = get_gradient_sensitivity(
            cot_text, rob_tokenizer, rob_model, device, target_class=1
        )
        sorted_sens = sorted(sensitivities.items(), key=lambda x: x[1], reverse=True)
        critical_tokens = [t[0] for t in sorted_sens if len(t[0]) >= 4][:5]
        print(f"  Crit.Tokens: {critical_tokens}")
    else:
        critical_tokens = []

    return {
        "tweet": tweet,
        "cot_text": cot_text,
        "entropy": entropy,
        "gamma_dyn": gamma_dyn,
        "critical_tokens": critical_tokens,
        "mode": mode
    }


# ════════════════════════════════════════════════════════════════════════════
# EXECUTION LOOP
# ════════════════════════════════════════════════════════════════════════════
CURRENT_MODE = "FULL_RDS"
NUM_SAMPLES   = 100

results_list       = []
correct_predictions = 0

print(f"🚀 Starting RDS v2 Pipeline  [{CURRENT_MODE} mode  |  N={NUM_SAMPLES}]")
print(f"   Upgrades: structured verdict prompt + entropy-adaptive alpha\n")

for i in range(NUM_SAMPLES):
    sample_tweet = test_data[i]["text"]
    true_label   = test_data[i]["label"]

    # 1. Generate CoT + compute entropy + extract critical tokens
    # CHANGED: Passed (i + 1) to show exactly which tweet is being processed (1 to 100)
    result_dict = generate_cot_and_analyze_v2(sample_tweet, mode=CURRENT_MODE, tweet_num=i+1)

    # 2. Compress CoT FIRST using the dynamic budget + critical-token protection
    compressed_text = compress_cot_improved(
        result_dict["cot_text"],
        result_dict["gamma_dyn"],
        result_dict["critical_tokens"]
    )

    # 3. THEN classify using the COMPRESSED CoT  ← main upgrade
    prediction, p_roberta, cot_signal, alpha, p_fused = fused_classify_v2(
        sample_tweet,
        compressed_text,            # ← was result_dict["cot_text"]
        result_dict["entropy"],
        rob_tokenizer, rob_model, device
    )

    is_correct = (prediction == true_label)
    if is_correct:
        correct_predictions += 1

    print(f"  RoBERTa={p_roberta:.3f} | CoT={cot_signal:.1f} | α={alpha:.3f} "
          f"| Fused={p_fused:.3f} | Pred={prediction} | True={true_label} "
          f"| {'✅' if is_correct else '❌'}")

    results_list.append({
        "Tweet"             : sample_tweet[:35] + "...",
        "True"              : true_label,
        "Pred"              : prediction,
        "✓?"                : "✅" if is_correct else "❌",
        "RoBERTa P(ironic)" : round(p_roberta, 3),
        "CoT Verdict"       : cot_signal,
        "α (adaptive)"      : round(alpha, 3),
        "Fused P(ironic)"   : round(p_fused, 3),
        "Entropy"           : round(result_dict["entropy"], 3),
        "Gamma"             : round(result_dict["gamma_dyn"], 3),
        "Orig Len"          : len(result_dict["cot_text"].split()),
        "Comp Len"          : len(compressed_text.split()),
    })

accuracy_pct = (correct_predictions / NUM_SAMPLES) * 100
skip_ratio   = sum(1 - r["Comp Len"]/r["Orig Len"] for r in results_list) / NUM_SAMPLES

print(f"\n{'='*64}")
print(f"🏆 RDS v2 [{CURRENT_MODE}] ACCURACY : {accuracy_pct:.1f}%  ({correct_predictions}/{NUM_SAMPLES})")
print(f"📉 Avg Token-Skip Ratio         : {skip_ratio:.1%}")
print(f"⚖️  Alpha range used             : [{0.35:.2f} – {0.75:.2f}] (entropy-gated)")
print(f"{'='*64}")

df = pd.DataFrame(results_list)
display(df)
# Out:
# 🚀 Starting RDS v2 Pipeline  [FULL_RDS mode  |  N=100]
#    Upgrades: structured verdict prompt + entropy-adaptive alpha
#
#
# --- Processing Tweet 1: @user Can U Help?||More conservatives needed on #TSU + get p... ---
#   CoT Length : 86 words
#   Entropy    : 0.374  →  Gamma: 0.475
#   Crit.Tokens: ['ervatives', 'ambiguous', 'ironic', 'neutral', 'cons']
#   RoBERTa=0.303 | CoT=1.0 | α=0.724 | Fused=0.496 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 2: Just walked in to #Starbucks and asked for a "tall blonde" H... ---
#   CoT Length : 84 words
#   Entropy    : 0.386  →  Gamma: 0.477
#   Crit.Tokens: ['ironic', 'irony', 'dict', 'Therefore', 'RESP']
#   RoBERTa=0.650 | CoT=1.0 | α=0.736 | Fused=0.742 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 3: #NOT GONNA WIN... ---
#   CoT Length : 91 words
#   Entropy    : 0.421  →  Gamma: 0.484
#   Crit.Tokens: ['Step', 'Consider', 'Analy', 'However', 'contradiction']
#   RoBERTa=0.033 | CoT=0.5 | α=0.771 | Fused=0.140 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 4: @user He is exactly that sort of person. Weirdo!... ---
#   CoT Length : 47 words
#   Entropy    : 0.515  →  Gamma: 0.503
#   Crit.Tokens: ['dict', 'iron', 'implies', 'critique', 'sarcastic']
#   RoBERTa=0.209 | CoT=0.0 | α=0.850 | Fused=0.178 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 5: So much #sarcasm at work mate 10/10 #boring 100% #dead mate ... ---
#   CoT Length : 87 words
#   Entropy    : 0.421  →  Gamma: 0.484
#   Crit.Tokens: ['irony', 'ironic', 'mocking', 'dict', 'tone']
#   RoBERTa=0.075 | CoT=1.0 | α=0.771 | Fused=0.287 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 6: Corny jokes are my absolute favorite... ---
#   CoT Length : 91 words
#   Entropy    : 0.352  →  Gamma: 0.471
#   Crit.Tokens: ['subsequent', 'However', 'first', 'This', 'contradiction']
#   RoBERTa=0.981 | CoT=0.5 | α=0.702 | Fused=0.838 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 7: People complain about my backround pic and all I feel is lik... ---
#   CoT Length : 72 words
#   Entropy    : 0.372  →  Gamma: 0.474
#   Crit.Tokens: ['ONLY', 'dict', 'RESP', 'author', 'criticized']
#   RoBERTa=0.269 | CoT=1.0 | α=0.722 | Fused=0.472 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 8: @user @user Darn, my sock joke needs fixing?... ---
#   CoT Length : 61 words
#   Entropy    : 0.534  →  Gamma: 0.507
#   Crit.Tokens: ['dict', 'Without', 'ironic', 'intent', 'context']
#   RoBERTa=0.090 | CoT=0.0 | α=0.850 | Fused=0.076 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 9: if Christian expects Fifa to sleep in my bed with me tonight... ---
#   CoT Length : 91 words
#   Entropy    : 0.475  →  Gamma: 0.495
#   Crit.Tokens: ['Christian', 'Consider', 'hearted', 'playful', 'There']
#   RoBERTa=0.031 | CoT=0.5 | α=0.825 | Fused=0.113 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 10: People who tell people with anxiety to "just stop worrying a... ---
#   CoT Length : 80 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['ironic', 'irony', 'educ', 'dict', 'emphasizes']
#   RoBERTa=0.866 | CoT=1.0 | α=0.685 | Fused=0.908 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 11: Most important thing I've learned in school... ---
#   CoT Length : 91 words
#   Entropy    : 0.512  →  Gamma: 0.502
#   Crit.Tokens: ['liberating', 'liber', 'Step', 'have', 'Consider']
#   RoBERTa=0.910 | CoT=0.5 | α=0.850 | Fused=0.848 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 12: #OrionLaunch underway - yeah! #Orion... ---
#   CoT Length : 45 words
#   Entropy    : 0.490  →  Gamma: 0.498
#   Crit.Tokens: ['dict', 'excitement', 'expressing', 'celebr', 'irony']
#   RoBERTa=0.359 | CoT=0.5 | α=0.840 | Fused=0.382 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 13: I love context and large ensemble Fridays!!!!! Der my most f... ---
#   CoT Length : 90 words
#   Entropy    : 0.413  →  Gamma: 0.483
#   Crit.Tokens: ['ensemble', 'Fridays', 'speaker', 'Step', 'Consider']
#   RoBERTa=0.904 | CoT=0.5 | α=0.763 | Fused=0.808 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 14: Oh boy... @user in the house. Warm up the DJ booth @user... ---
#   CoT Length : 79 words
#   Entropy    : 0.484  →  Gamma: 0.497
#   Crit.Tokens: ['ironic', 'dict', 'context', 'speaker', 'ironically']
#   RoBERTa=0.073 | CoT=1.0 | α=0.834 | Fused=0.227 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 15: LIAR, i've never denied the 532 murders in Chicago in 2012 @... ---
#   CoT Length : 81 words
#   Entropy    : 0.256  →  Gamma: 0.451
#   Crit.Tokens: ['2012', 'author', 'claiming', 'contradiction', 'that']
#   RoBERTa=0.059 | CoT=1.0 | α=0.606 | Fused=0.430 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 16: Always classy, never trashy and just a little sassy.... ---
#   CoT Length : 59 words
#   Entropy    : 0.361  →  Gamma: 0.472
#   Crit.Tokens: ['dict', 'ironic', 'indication', 'RESP', 'describes']
#   RoBERTa=0.090 | CoT=0.0 | α=0.711 | Fused=0.064 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 17: you believe you can say something, provide no proof and its ... ---
#   CoT Length : 86 words
#   Entropy    : 0.262  →  Gamma: 0.453
#   Crit.Tokens: ['Analysis', 'Tone', 'statement', 'Iron', 'Content']
#   RoBERTa=0.116 | CoT=0.5 | α=0.612 | Fused=0.265 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 18: @user #Not #Long To Go #Before #MainStream #Media #Pitch. #S... ---
#   CoT Length : 95 words
#   Entropy    : 0.523  →  Gamma: 0.505
#   Crit.Tokens: ['uses', 'Step', 'pitched', 'ironic', 'seeking']
#   RoBERTa=0.124 | CoT=1.0 | α=0.850 | Fused=0.255 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 19: @user Re: Jamie Grace has Tourette's? Thanks for sharing. I'... ---
#   CoT Length : 80 words
#   Entropy    : 0.219  →  Gamma: 0.444
#   Crit.Tokens: ['contradiction', 'Identification', 'tribute', 'Iron', 'thanks']
#   RoBERTa=0.050 | CoT=1.0 | α=0.569 | Fused=0.460 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 20: @user Guess they didn't get the memo reg non-nuclear Baltic ... ---
#   CoT Length : 90 words
#   Entropy    : 0.344  →  Gamma: 0.469
#   Crit.Tokens: ['Deter', 'there', 'Step', 'misunderstanding', 'Baltic']
#   RoBERTa=0.486 | CoT=0.5 | α=0.694 | Fused=0.491 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 21: Exam na jud. Merry christmas. ||#Sarcasm|#KillUsSlowly... ---
#   CoT Length : 90 words
#   Entropy    : 0.511  →  Gamma: 0.502
#   Crit.Tokens: ['dict', 'Given', 'Kill', 'context', 'ironic']
#   RoBERTa=0.155 | CoT=1.0 | α=0.850 | Fused=0.282 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 22: The definition of #IRONY would be if a 77-year-old rapper we... ---
#   CoT Length : 76 words
#   Entropy    : 0.275  →  Gamma: 0.455
#   Crit.Tokens: ['starts', 'context', 'tweet', 'suggests', 'step']
#   RoBERTa=0.815 | CoT=0.5 | α=0.625 | Fused=0.697 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 23: Pretty excited about how you gave up on me. File Under: #sar... ---
#   CoT Length : 97 words
#   Entropy    : 0.457  →  Gamma: 0.491
#   Crit.Tokens: ['given', 'excitement', 'hashtag', 'Step', 'romantic']
#   RoBERTa=0.508 | CoT=0.5 | α=0.807 | Fused=0.507 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 24: Who told the #hipsters that #irony was a thing of the Clinto... ---
#   CoT Length : 83 words
#   Entropy    : 0.408  →  Gamma: 0.482
#   Crit.Tokens: ['dict', 'Therefore', 'described', 'irony', 'straightforward']
#   RoBERTa=0.348 | CoT=0.0 | α=0.758 | Fused=0.263 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 25: @user u know that. How u doing??... ---
#   CoT Length : 98 words
#   Entropy    : 0.381  →  Gamma: 0.476
#   Crit.Tokens: ['Step', 'greeting', 'inquiry', 'ironic', 'irony']
#   RoBERTa=0.026 | CoT=0.5 | α=0.731 | Fused=0.153 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 26: @user hmm... let me think about that #sarcasm... ---
#   CoT Length : 57 words
#   Entropy    : 0.416  →  Gamma: 0.483
#   Crit.Tokens: ['dict', 'ironic', 'indicates', 'sarc', 'obvious']
#   RoBERTa=0.088 | CoT=1.0 | α=0.766 | Fused=0.301 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 27: If you wanna look like a badass, have drama on social media ... ---
#   CoT Length : 53 words
#   Entropy    : 0.389  →  Gamma: 0.478
#   Crit.Tokens: ['ironic', 'dict', 'badass', 'contradiction', 'RESP']
#   RoBERTa=0.703 | CoT=1.0 | α=0.739 | Fused=0.780 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 28: How dare Charles Barkley have an intelligent conversation ab... ---
#   CoT Length : 90 words
#   Entropy    : 0.349  →  Gamma: 0.470
#   Crit.Tokens: ['arises', 'ironic', 'dict', 'irony', 'Barkley']
#   RoBERTa=0.355 | CoT=1.0 | α=0.699 | Fused=0.549 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 29: @user I think the general rule is, if it's open all night, p... ---
#   CoT Length : 83 words
#   Entropy    : 0.329  →  Gamma: 0.466
#   Crit.Tokens: ['notations', 'dict', 'suggests', 'typically', 'Consider']
#   RoBERTa=0.055 | CoT=1.0 | α=0.679 | Fused=0.359 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 30: Natalie Prass - Bird of Prey: via @user... ---
#   CoT Length : 55 words
#   Entropy    : 0.271  →  Gamma: 0.454
#   Crit.Tokens: ['irony', 'participating', 'Natalie', 'notification', 'Bird']
#   RoBERTa=0.029 | CoT=0.0 | α=0.621 | Fused=0.018 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 31: Nooooooooooo again it's on!!! #PickANewSong #CantStandIt... ---
#   CoT Length : 79 words
#   Entropy    : 0.405  →  Gamma: 0.481
#   Crit.Tokens: ['occurrence', 'dict', 'Step', 'analysis', 'repetition']
#   RoBERTa=0.266 | CoT=1.0 | α=0.755 | Fused=0.446 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 32: Being a hipster now is so mainstream. Oh, the irony. #hipste... ---
#   CoT Length : 91 words
#   Entropy    : 0.344  →  Gamma: 0.469
#   Crit.Tokens: ['unique', 'Context', 'irony', 'hashtag', 'mainstream']
#   RoBERTa=0.922 | CoT=0.5 | α=0.694 | Fused=0.793 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 33: @user exactly and we are fighting like animals... ---
#   CoT Length : 30 words
#   Entropy    : 0.048  →  Gamma: 0.411
#   Crit.Tokens: []
#   RoBERTa=0.351 | CoT=0.5 | α=0.550 | Fused=0.418 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 34: #TeenAnalCasting #Top Top 50 Christian Songs For 2012... ---
#   CoT Length : 84 words
#   Entropy    : 0.404  →  Gamma: 0.481
#   Crit.Tokens: ['informative', 'ironic', 'neutral', 'lack', 'casting']
#   RoBERTa=0.111 | CoT=0.5 | α=0.754 | Fused=0.207 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 35: The girls on #SororitySisters thought they'd get rich and fa... ---
#   CoT Length : 96 words
#   Entropy    : 0.531  →  Gamma: 0.506
#   Crit.Tokens: ['ambitions', 'Step', 'amine', 'tone', 'implications']
#   RoBERTa=0.865 | CoT=0.5 | α=0.850 | Fused=0.810 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 36: Speaking of #country #music albums, anyone else think #Sundo... ---
#   CoT Length : 88 words
#   Entropy    : 0.446  →  Gamma: 0.489
#   Crit.Tokens: ['implying', 'irony', 'dict', 'that', 'indicates']
#   RoBERTa=0.045 | CoT=1.0 | α=0.796 | Fused=0.240 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 37: #TeenAnalCasting #Sex Sex and the City 2 Movie Casting Audit... ---
#   CoT Length : 80 words
#   Entropy    : 0.331  →  Gamma: 0.466
#   Crit.Tokens: ['dict', 'nature', 'However', 'reasoning', 'adaptation']
#   RoBERTa=0.170 | CoT=1.0 | α=0.681 | Fused=0.435 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 38: season 6 episode 3 carries outfit, simple & chic 👌... ---
#   CoT Length : 81 words
#   Entropy    : 0.361  →  Gamma: 0.472
#   Crit.Tokens: ['dict', 'anticipated', 'appearances', 'fashion', 'statement']
#   RoBERTa=0.089 | CoT=0.0 | α=0.711 | Fused=0.063 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 39: Well got the truck buried today perfect way to start a rainy... ---
#   CoT Length : 94 words
#   Entropy    : 0.496  →  Gamma: 0.499
#   Crit.Tokens: ['Despite', 'conve', 'relief', 'Step', 'Consider']
#   RoBERTa=0.566 | CoT=0.5 | α=0.846 | Fused=0.555 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 40: On the train and surrounded by posh people, I'm so at home! ... ---
#   CoT Length : 74 words
#   Entropy    : 0.305  →  Gamma: 0.461
#   Crit.Tokens: ['dict', 'contradiction', 'creates', 'However', 'environment']
#   RoBERTa=0.665 | CoT=1.0 | α=0.655 | Fused=0.780 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 41: Stupid #doctors visits is gonna bury me!! Now that's #irony... ---
#   CoT Length : 92 words
#   Entropy    : 0.502  →  Gamma: 0.500
#   Crit.Tokens: ['dict', 'irony', 'essence', 'mundane', 'doctors']
#   RoBERTa=0.549 | CoT=1.0 | α=0.850 | Fused=0.617 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 42: Love the way @user says fault from last night will be fixed ... ---
#   CoT Length : 86 words
#   Entropy    : 0.345  →  Gamma: 0.469
#   Crit.Tokens: ['suggests', 'irony', 'promise', 'mentions', 'meanings']
#   RoBERTa=0.961 | CoT=1.0 | α=0.695 | Fused=0.973 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 43: Planning a vacation instead of studying.... My priorities ar... ---
#   CoT Length : 91 words
#   Entropy    : 0.334  →  Gamma: 0.467
#   Crit.Tokens: ['Analysis', 'suggesting', 'However', 'studying', 'ironic']
#   RoBERTa=0.624 | CoT=0.5 | α=0.684 | Fused=0.585 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 44: Dan said he's going to have a sign for me at the airport whe... ---
#   CoT Length : 86 words
#   Entropy    : 0.318  →  Gamma: 0.464
#   Crit.Tokens: ['straightforward', 'welcoming', 'dict', 'elements', 'promising']
#   RoBERTa=0.362 | CoT=1.0 | α=0.668 | Fused=0.574 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 45: You decide to go on vacation without me sleep? Reaaaal nice.... ---
#   CoT Length : 88 words
#   Entropy    : 0.413  →  Gamma: 0.483
#   Crit.Tokens: ['irony', 'Step', 'sentiment', 'suggesting', 'Eval']
#   RoBERTa=0.188 | CoT=0.5 | α=0.763 | Fused=0.262 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 46: @user No sugar during christmas time? :(... ---
#   CoT Length : 93 words
#   Entropy    : 0.361  →  Gamma: 0.472
#   Crit.Tokens: ['Step', 'cakes', 'Consider', 'implies', 'cookies']
#   RoBERTa=0.125 | CoT=0.5 | α=0.711 | Fused=0.233 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 47: Can't wait to have an afternoon schedule because of you. It'... ---
#   CoT Length : 85 words
#   Entropy    : 0.446  →  Gamma: 0.489
#   Crit.Tokens: ['dict', 'boredom', 'reasoning', 'contradicts', 'generally']
#   RoBERTa=0.970 | CoT=1.0 | α=0.796 | Fused=0.976 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 48: @user 180 dead on 26/11 n more than 10k our ppl killed in te... ---
#   CoT Length : 80 words
#   Entropy    : 0.308  →  Gamma: 0.462
#   Crit.Tokens: ['recognition', 'reasoning', 'Iron', 'step', 'mentioning']
#   RoBERTa=0.286 | CoT=1.0 | α=0.658 | Fused=0.530 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 49: the ONLY time a crime becomes a federal crime @user @user @u... ---
#   CoT Length : 7 words
#   Entropy    : 0.062  →  Gamma: 0.414
#   Crit.Tokens: ['dict']
#   RoBERTa=0.090 | CoT=0.5 | α=0.550 | Fused=0.275 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 50: this music is for the people and not for the money. peace an... ---
#   CoT Length : 94 words
#   Entropy    : 0.507  →  Gamma: 0.501
#   Crit.Tokens: ['dict', 'ironic', 'KING', 'expressed', 'monetary']
#   RoBERTa=0.101 | CoT=0.0 | α=0.850 | Fused=0.086 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 51: Rangers league game with Alloa moved because of the Petrofac... ---
#   CoT Length : 76 words
#   Entropy    : 0.351  →  Gamma: 0.470
#   Crit.Tokens: ['paradox', 'ironic', 'irony', 'delayed', 'situation']
#   RoBERTa=0.565 | CoT=1.0 | α=0.701 | Fused=0.695 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 52: How to Find a Life Coach (& the questions you need to ask be... ---
#   CoT Length : 91 words
#   Entropy    : 0.333  →  Gamma: 0.467
#   Crit.Tokens: ['contradiction', 'irony', 'informative', 'coach', 'analysis']
#   RoBERTa=0.033 | CoT=0.5 | α=0.683 | Fused=0.181 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 53: I wonder what was the holiday rituals for true Africans... ---
#   CoT Length : 91 words
#   Entropy    : 0.525  →  Gamma: 0.505
#   Crit.Tokens: ['However', 'dict', 'irony', 'ironic', 'observation']
#   RoBERTa=0.209 | CoT=0.0 | α=0.850 | Fused=0.178 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 54: Been at the ER now since 10... #yay #not... ---
#   CoT Length : 71 words
#   Entropy    : 0.341  →  Gamma: 0.468
#   Crit.Tokens: ['ironic', 'hasht', 'dict', 'irony', 'emergency']
#   RoBERTa=0.344 | CoT=1.0 | α=0.691 | Fused=0.547 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 55: @user Suhs been clean for 2 years and has only been in the l... ---
#   CoT Length : 84 words
#   Entropy    : 0.293  →  Gamma: 0.459
#   Crit.Tokens: ['discussing', 'Step', 'implicit', 'league', 'dirty']
#   RoBERTa=0.041 | CoT=0.5 | α=0.643 | Fused=0.205 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 56: @user @user thank you studs for perfecting and teaching my b... ---
#   CoT Length : 90 words
#   Entropy    : 0.398  →  Gamma: 0.480
#   Crit.Tokens: ['Given', 'There', 'judgment', 'Final', 'bench']
#   RoBERTa=0.643 | CoT=0.5 | α=0.748 | Fused=0.607 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 57: Haley approves of her new hammock 🐭 #ratsofinstagram... ---
#   CoT Length : 87 words
#   Entropy    : 0.369  →  Gamma: 0.474
#   Crit.Tokens: ['approving', 'indication', 'Haley', 'seems', 'straightforward']
#   RoBERTa=0.187 | CoT=0.5 | α=0.719 | Fused=0.275 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 58: 30 years on, people still haven't got justice they deserve. ... ---
#   CoT Length : 74 words
#   Entropy    : 0.411  →  Gamma: 0.482
#   Crit.Tokens: ['dict', 'sarcast', 'irony', 'mockery', 'tone']
#   RoBERTa=0.915 | CoT=1.0 | α=0.761 | Fused=0.935 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 59: Pips who drop out of school n have Kirya as 'eir role model ... ---
#   CoT Length : 92 words
#   Entropy    : 0.393  →  Gamma: 0.479
#   Crit.Tokens: ['unlikely', 'creates', 'ironic', 'Step', 'PLEASE']
#   RoBERTa=0.289 | CoT=0.5 | α=0.743 | Fused=0.343 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 60: Free Pets and Animals Books #freebiebookdownload #Pets... ---
#   CoT Length : 96 words
#   Entropy    : 0.341  →  Gamma: 0.468
#   Crit.Tokens: ['implication', 'announcement', 'Step', 'promotion', 'irony']
#   RoBERTa=0.155 | CoT=0.5 | α=0.691 | Fused=0.261 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 61: @user There will be no next employer in NFL for Trestman. He... ---
#   CoT Length : 88 words
#   Entropy    : 0.263  →  Gamma: 0.453
#   Crit.Tokens: ['unemploy', 'suggesting', 'employers', 'expresses', 'able']
#   RoBERTa=0.081 | CoT=0.5 | α=0.613 | Fused=0.243 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 62: Loooovvveeeeeee when my phone gets wiped -.- #not... ---
#   CoT Length : 89 words
#   Entropy    : 0.375  →  Gamma: 0.475
#   Crit.Tokens: ['wiping', 'suggests', 'irony', 'contains', 'wiped']
#   RoBERTa=0.306 | CoT=0.5 | α=0.725 | Fused=0.360 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 63: Painting all cops with a broad brush because of the actions ... ---
#   CoT Length : 5 words
#   Entropy    : 0.224  →  Gamma: 0.445
#   Crit.Tokens: ['dict', 'RESP']
#   RoBERTa=0.861 | CoT=1.0 | α=0.574 | Fused=0.920 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 64: Don't know if I can handle this crazy 11-2 shift. It's so lo... ---
#   CoT Length : 10 words
#   Entropy    : 0.128  →  Gamma: 0.426
#   Crit.Tokens: ['RESP', 'dict']
#   RoBERTa=0.084 | CoT=0.5 | α=0.550 | Fused=0.271 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 65: I just love being ignored😊|#not😒... ---
#   CoT Length : 93 words
#   Entropy    : 0.442  →  Gamma: 0.488
#   Crit.Tokens: ['ironic', 'twist', 'suggests', 'values', 'Eval']
#   RoBERTa=0.180 | CoT=0.5 | α=0.792 | Fused=0.247 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 66: #Irony RT @user If you're going to give someone a scathing, ... ---
#   CoT Length : 90 words
#   Entropy    : 0.408  →  Gamma: 0.482
#   Crit.Tokens: ['review', 'occurs', 'negative', 'reviews', 'determine']
#   RoBERTa=0.295 | CoT=0.5 | α=0.758 | Fused=0.344 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 67: Produce Mobile Apps #not... ---
#   CoT Length : 98 words
#   Entropy    : 0.552  →  Gamma: 0.510
#   Crit.Tokens: ['Analy', 'creates', 'irony', 'Step', 'Ident']
#   RoBERTa=0.319 | CoT=0.5 | α=0.850 | Fused=0.346 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 68: Decide that you want it more than you are afraid of it. -Bil... ---
#   CoT Length : 93 words
#   Entropy    : 0.351  →  Gamma: 0.470
#   Crit.Tokens: ['Given', 'Cosby', 'Step', 'motivational', 'encouragement']
#   RoBERTa=0.077 | CoT=0.5 | α=0.701 | Fused=0.204 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 69: Finally finished the first season of #VeronicaMars. Move ove... ---
#   CoT Length : 74 words
#   Entropy    : 0.287  →  Gamma: 0.458
#   Crit.Tokens: ['contradiction', 'because', 'There', 'ironic', 'Step']
#   RoBERTa=0.103 | CoT=1.0 | α=0.637 | Fused=0.429 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 70: Merry Christmas to all those soldiers out there that couldn'... ---
#   CoT Length : 101 words
#   Entropy    : 0.392  →  Gamma: 0.478
#   Crit.Tokens: ['deployed', 'sentiment', 'Step', 'expressed', 'Consider']
#   RoBERTa=0.041 | CoT=0.0 | α=0.742 | Fused=0.030 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 71: About as relevant as Michael Sam and Jason Collins. RT @user... ---
#   CoT Length : 58 words
#   Entropy    : 0.440  →  Gamma: 0.488
#   Crit.Tokens: ['dict', 'ironic', 'tone', 'creates', 'juxtap']
#   RoBERTa=0.788 | CoT=1.0 | α=0.790 | Fused=0.833 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 72: Getting Final Jeopardy correct on Kids Jeopardy boosts my se... ---
#   CoT Length : 85 words
#   Entropy    : 0.263  →  Gamma: 0.453
#   Crit.Tokens: ['questions', 'Analysis', 'typically', 'challenging', 'boost']
#   RoBERTa=0.966 | CoT=0.5 | α=0.613 | Fused=0.786 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 73: itsfunny bc people think im quiet|but im just listening toev... ---
#   CoT Length : 7 words
#   Entropy    : 0.063  →  Gamma: 0.414
#   Crit.Tokens: ['dict']
#   RoBERTa=0.093 | CoT=0.5 | α=0.550 | Fused=0.276 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 74: Woke Up , showered , made a lunch and got ready for work onl... ---
#   CoT Length : 57 words
#   Entropy    : 0.253  →  Gamma: 0.451
#   Crit.Tokens: ['dict', 'ironic', 'scenario', 'exaggeration', 'thus']
#   RoBERTa=0.603 | CoT=0.0 | α=0.603 | Fused=0.364 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 75: @user @user @user @user @user How many of those jobs earn #m... ---
#   CoT Length : 89 words
#   Entropy    : 0.353  →  Gamma: 0.471
#   Crit.Tokens: ['scenario', 'described', 'rhetorical', 'implies', 'Step']
#   RoBERTa=0.096 | CoT=0.5 | α=0.703 | Fused=0.216 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 76: I reckon straight women fancy victoria secret models more th... ---
#   CoT Length : 93 words
#   Entropy    : 0.318  →  Gamma: 0.464
#   Crit.Tokens: ['irony', 'Deter', 'ironic', 'Step', 'perceived']
#   RoBERTa=0.879 | CoT=0.5 | α=0.668 | Fused=0.753 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 77: Incredible insight on the @user #bornrisky campaign: #ampute... ---
#   CoT Length : 94 words
#   Entropy    : 0.500  →  Gamma: 0.500
#   Crit.Tokens: ['Step', 'potential', 'irony', 'contradiction', 'implications']
#   RoBERTa=0.311 | CoT=0.5 | α=0.850 | Fused=0.340 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 78: Love #hiphop mix tapes or have a mixtape to promote check ou... ---
#   CoT Length : 86 words
#   Entropy    : 0.317  →  Gamma: 0.464
#   Crit.Tokens: ['casual', 'contradiction', 'encouraging', 'hasht', 'apparent']
#   RoBERTa=0.057 | CoT=0.5 | α=0.667 | Fused=0.204 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 79: Extended cut "NICHA" #trailer #spoof #film #dramatic #action... ---
#   CoT Length : 80 words
#   Entropy    : 0.387  →  Gamma: 0.477
#   Crit.Tokens: ['ironic', 'Analysis', 'trailers', 'Content', 'interpreted']
#   RoBERTa=0.210 | CoT=1.0 | α=0.737 | Fused=0.418 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 80: @user Stunning work. #british #textiles #footwear #madeinbri... ---
#   CoT Length : 91 words
#   Entropy    : 0.476  →  Gamma: 0.495
#   Crit.Tokens: ['dict', 'This', 'innovation', 'ironic', 'implicitly']
#   RoBERTa=0.378 | CoT=1.0 | α=0.826 | Fused=0.486 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 81: @user @user Sent it but too slow. I had already posted.... ---
#   CoT Length : 100 words
#   Entropy    : 0.396  →  Gamma: 0.479
#   Crit.Tokens: ['context', 'humorous', 'contrast', 'Consider', 'Step']
#   RoBERTa=0.046 | CoT=0.5 | α=0.746 | Fused=0.161 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 82: #FEMALECONDOM #anally #vaginally #prevent STD's/HIV/pregnanc... ---
#   CoT Length : 69 words
#   Entropy    : 0.314  →  Gamma: 0.463
#   Crit.Tokens: ['appears', 'preventing', 'includes', 'hasht', 'dict']
#   RoBERTa=0.160 | CoT=1.0 | α=0.664 | Fused=0.442 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 83: Little cutie #Chico #Dog #Doggy #Puppy #Sweet #Cute #UK #Bla... ---
#   CoT Length : 52 words
#   Entropy    : 0.328  →  Gamma: 0.466
#   Crit.Tokens: ['dict', 'ironic', 'Therefore', 'descript', 'affection']
#   RoBERTa=0.092 | CoT=0.0 | α=0.678 | Fused=0.062 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 84: @user Niagra Falls tho... Really? #irony #LOL... ---
#   CoT Length : 73 words
#   Entropy    : 0.414  →  Gamma: 0.483
#   Crit.Tokens: ['verdict', 'Final', 'dict', 'disbelief', 'agara']
#   RoBERTa=0.217 | CoT=0.5 | α=0.764 | Fused=0.284 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 85: If we win against Poland and Scotland, does that put us 65th... ---
#   CoT Length : 89 words
#   Entropy    : 0.448  →  Gamma: 0.490
#   Crit.Tokens: ['ironic', 'dict', 'exaggeration', 'implies', 'This']
#   RoBERTa=0.114 | CoT=1.0 | α=0.798 | Fused=0.293 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 86: #Myanmar #men #plead #not #guilty to #murder of #British #to... ---
#   CoT Length : 58 words
#   Entropy    : 0.510  →  Gamma: 0.502
#   Crit.Tokens: ['dict', 'pleading', 'Myanmar', 'ironic', 'tourists']
#   RoBERTa=0.209 | CoT=0.0 | α=0.850 | Fused=0.178 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 87: Since the tribunal was established 14 years ago, no complain... ---
#   CoT Length : 90 words
#   Entropy    : 0.209  →  Gamma: 0.442
#   Crit.Tokens: ['Analysis', 'suggests', 'Content', 'However', 'discusses']
#   RoBERTa=0.561 | CoT=0.5 | α=0.559 | Fused=0.534 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 88: @user Garner protesters chant 'F*ck Fox News' despite Fox ag... ---
#   CoT Length : 88 words
#   Entropy    : 0.295  →  Gamma: 0.459
#   Crit.Tokens: ['situation', 'described', 'dict', 'ironic', 'Step']
#   RoBERTa=0.812 | CoT=1.0 | α=0.645 | Fused=0.879 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 89: @user After 1989, why did NATO need to expand?... ---
#   CoT Length : 87 words
#   Entropy    : 0.331  →  Gamma: 0.466
#   Crit.Tokens: ['dict', 'ironic', 'curiosity', 'RESP', 'tweet']
#   RoBERTa=0.169 | CoT=0.0 | α=0.681 | Fused=0.115 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 90: The #Irony of playing this song on my way to #work |#NoMoney... ---
#   CoT Length : 85 words
#   Entropy    : 0.413  →  Gamma: 0.483
#   Crit.Tokens: ['Nonetheless', 'dict', 'ironic', 'Cook', 'sentiment']
#   RoBERTa=0.204 | CoT=0.0 | α=0.763 | Fused=0.156 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet 91: You are taking your responsibilities so seriously today that... ---
#   CoT Length : 59 words
#   Entropy    : 0.496  →  Gamma: 0.499
#   Crit.Tokens: ['responsibilities', 'dict', 'irony', 'about', 'taking']
#   RoBERTa=0.767 | CoT=0.5 | α=0.846 | Fused=0.726 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 92: @user @user @user @user @user we get it right for business t... ---
#   CoT Length : 89 words
#   Entropy    : 0.482  →  Gamma: 0.496
#   Crit.Tokens: ['ironic', 'dict', 'RESP', 'indeed', 'mocking']
#   RoBERTa=0.473 | CoT=1.0 | α=0.832 | Fused=0.561 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 93: can you not understand that not EVERYTHING is about the Pres... ---
#   CoT Length : 66 words
#   Entropy    : 0.350  →  Gamma: 0.470
#   Crit.Tokens: ['dict', 'sender', 'addressing', 'interpreted', 'irony']
#   RoBERTa=0.070 | CoT=0.0 | α=0.700 | Fused=0.049 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 94: When you're in the doctors waiting room and hear a baby in t... ---
#   CoT Length : 96 words
#   Entropy    : 0.323  →  Gamma: 0.465
#   Crit.Tokens: ['described', 'irony', 'contradiction', 'Step', 'Consider']
#   RoBERTa=0.971 | CoT=0.5 | α=0.673 | Fused=0.817 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 95: Well now the festive season has begun, let's take a moment t... ---
#   CoT Length : 94 words
#   Entropy    : 0.363  →  Gamma: 0.473
#   Crit.Tokens: ['There', 'double', 'Step', 'irony', 'Ident']
#   RoBERTa=0.616 | CoT=0.5 | α=0.713 | Fused=0.583 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet 96: The last day of the year and I will be tweeting on my major ... ---
#   CoT Length : 87 words
#   Entropy    : 0.345  →  Gamma: 0.469
#   Crit.Tokens: ['dict', 'aspects', 'ironic', 'speaker', 'However']
#   RoBERTa=0.133 | CoT=1.0 | α=0.695 | Fused=0.397 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 97: MB forgot to move the elf on shelf and now 10 is asking me i... ---
#   CoT Length : 92 words
#   Entropy    : 0.254  →  Gamma: 0.451
#   Crit.Tokens: ['analysis', 'oversight', 'Context', 'forgetting', 'Iron']
#   RoBERTa=0.629 | CoT=0.0 | α=0.604 | Fused=0.380 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 98: @user happy new year, da! Thanks sobra for this year 👍👍... ---
#   CoT Length : 94 words
#   Entropy    : 0.381  →  Gamma: 0.476
#   Crit.Tokens: ['Step', 'expressing', 'contradiction', 'Analy', 'appreciation']
#   RoBERTa=0.095 | CoT=0.5 | α=0.731 | Fused=0.204 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet 99: WATCH: #Megatron from #Transformers Rant About Social Media ... ---
#   CoT Length : 92 words
#   Entropy    : 0.355  →  Gamma: 0.471
#   Crit.Tokens: ['Analysis', 'irony', 'explanation', 'robotic', 'Iron']
#   RoBERTa=0.515 | CoT=0.5 | α=0.705 | Fused=0.511 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet 100: @user @user #not #working when are we able to download games... ---
#   CoT Length : 85 words
#   Entropy    : 0.315  →  Gamma: 0.463
#   Crit.Tokens: ['irony', 'Ident', 'Step', 'potential', 'downloads']
#   RoBERTa=0.075 | CoT=1.0 | α=0.665 | Fused=0.385 | Pred=0 | True=0 | ✅
#
# ================================================================
# 🏆 RDS v2 [FULL_RDS] ACCURACY : 74.0%  (74/100)
# 📉 Avg Token-Skip Ratio         : 47.4%
# ⚖️  Alpha range used             : [0.35 – 0.75] (entropy-gated)
# ================================================================
#                                      Tweet  True  Pred ✓?  RoBERTa P(ironic)  \
# 0   @user Can U Help?||More conservativ...     0     0  ✅              0.303
# 1   Just walked in to #Starbucks and as...     1     1  ✅              0.650
# 2                        #NOT GONNA WIN...     0     0  ✅              0.033
# 3   @user He is exactly that sort of pe...     0     0  ✅              0.209
# 4   So much #sarcasm at work mate 10/10...     1     0  ❌              0.075
# ..                                     ...   ...   ... ..                ...
# 95  The last day of the year and I will...     0     0  ✅              0.133
# 96  MB forgot to move the elf on shelf ...     0     0  ✅              0.629
# 97  @user happy new year, da! Thanks so...     0     0  ✅              0.095
# 98  WATCH: #Megatron from #Transformers...     0     1  ❌              0.515
# 99  @user @user #not #working when are ...     0     0  ✅              0.075
#
#     CoT Verdict  α (adaptive)  Fused P(ironic)  Entropy  Gamma  Orig Len  \
# 0           1.0         0.724            0.496    0.374  0.475        86
# 1           1.0         0.736            0.742    0.386  0.477        84
# 2           0.5         0.771            0.140    0.421  0.484        91
# 3           0.0         0.850            0.178    0.515  0.503        47
# 4           1.0         0.771            0.287    0.421  0.484        87
# ..          ...           ...              ...      ...    ...       ...
# 95          1.0         0.695            0.397    0.345  0.469        87
# 96          0.0         0.604            0.380    0.254  0.451        92
# 97          0.5         0.731            0.204    0.381  0.476        94
# 98          0.5         0.705            0.511    0.355  0.471        92
# 99          1.0         0.665            0.385    0.315  0.463        85
#
#     Comp Len
# 0         45
# 1         43
# 2         46
# 3         23
# 4         44
# ..       ...
# 95        46
# 96        50
# 97        49
# 98        48
# 99        45
#
# [100 rows x 12 columns]

# %% [markdown]
# Ablation Study (Entropy Only and Gradient only)

# %% [markdown]
# Entropy Only

# %%
import torch
import pandas as pd
from IPython.display import display

CURRENT_MODE = "ENTROPY_ONLY"
NUM_SAMPLES  = 100

results_list        = []
correct_predictions = 0

print(f"🚀 Starting RDS v2 Pipeline in {CURRENT_MODE} mode...")
print(f"   Upgrades: structured verdict prompt + entropy-adaptive alpha\n")

for i in range(NUM_SAMPLES):
    sample_tweet = test_data[i]["text"]
    true_label   = test_data[i]["label"]

    # 1. Generate CoT + entropy (no gradient step in ENTROPY_ONLY)
    result_dict = generate_cot_and_analyze_v2(sample_tweet, mode=CURRENT_MODE)

    # 2. Compress CoT FIRST using the dynamic budget + critical-token protection
    compressed_text = compress_cot_improved(
        result_dict["cot_text"],
        result_dict["gamma_dyn"],
        result_dict["critical_tokens"]
    )

    # 3. THEN classify using the COMPRESSED CoT
    prediction, p_roberta, cot_signal, alpha, p_fused = fused_classify_v2(
        sample_tweet,
        compressed_text,            # ← was result_dict["cot_text"]
        result_dict["entropy"],
        rob_tokenizer, rob_model, device
    )

    is_correct = (prediction == true_label)
    if is_correct:
        correct_predictions += 1

    print(f"  RoBERTa={p_roberta:.3f} | CoT={cot_signal:.1f} | α={alpha:.3f} "
          f"| Fused={p_fused:.3f} | Pred={prediction} | True={true_label} "
          f"| {'✅' if is_correct else '❌'}")

    results_list.append({
        "Tweet"             : sample_tweet[:35] + "...",
        "True"              : true_label,
        "Pred"              : prediction,
        "✓?"                : "✅" if is_correct else "❌",
        "RoBERTa P(ironic)" : round(p_roberta, 3),
        "CoT Verdict"       : cot_signal,
        "α (adaptive)"      : round(alpha, 3),
        "Fused P(ironic)"   : round(p_fused, 3),
        "Entropy"           : round(result_dict["entropy"], 3),
        "Gamma"             : round(result_dict["gamma_dyn"], 3),
        "Orig Len"          : len(result_dict["cot_text"].split()),
        "Comp Len"          : len(compressed_text.split()),
    })

accuracy_pct = (correct_predictions / NUM_SAMPLES) * 100
skip_ratio   = sum(1 - r["Comp Len"]/r["Orig Len"] for r in results_list) / NUM_SAMPLES

print(f"\n{'='*64}")
print(f"🏆 RDS v2 [{CURRENT_MODE}] ACCURACY : {accuracy_pct:.1f}%  ({correct_predictions}/{NUM_SAMPLES})")
print(f"📉 Avg Token-Skip Ratio         : {skip_ratio:.1%}")
print(f"⚖️  Alpha range used             : [0.35 – 0.75] (entropy-gated)")
print(f"{'='*64}")

df = pd.DataFrame(results_list)
display(df)
# Out:
# 🚀 Starting RDS v2 Pipeline in ENTROPY_ONLY mode...
#    Upgrades: structured verdict prompt + entropy-adaptive alpha
#
#
# --- Processing Tweet: @user Can U Help?||More conservatives needed on #TSU + get p... ---
#   CoT Length : 83 words
#   Entropy    : 0.369  →  Gamma: 0.474
#   RoBERTa=0.303 | CoT=1.0 | α=0.719 | Fused=0.499 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Just walked in to #Starbucks and asked for a "tall blonde" H... ---
#   CoT Length : 56 words
#   Entropy    : 0.479  →  Gamma: 0.496
#   RoBERTa=0.650 | CoT=1.0 | α=0.829 | Fused=0.710 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: #NOT GONNA WIN... ---
#   CoT Length : 94 words
#   Entropy    : 0.608  →  Gamma: 0.522
#   RoBERTa=0.033 | CoT=1.0 | α=0.850 | Fused=0.178 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: @user He is exactly that sort of person. Weirdo!... ---
#   CoT Length : 62 words
#   Entropy    : 0.440  →  Gamma: 0.488
#   RoBERTa=0.209 | CoT=0.5 | α=0.790 | Fused=0.270 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: So much #sarcasm at work mate 10/10 #boring 100% #dead mate ... ---
#   CoT Length : 93 words
#   Entropy    : 0.478  →  Gamma: 0.496
#   RoBERTa=0.075 | CoT=1.0 | α=0.828 | Fused=0.234 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: Corny jokes are my absolute favorite... ---
#   CoT Length : 84 words
#   Entropy    : 0.326  →  Gamma: 0.465
#   RoBERTa=0.981 | CoT=0.5 | α=0.676 | Fused=0.825 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet: People complain about my backround pic and all I feel is lik... ---
#   CoT Length : 95 words
#   Entropy    : 0.392  →  Gamma: 0.478
#   RoBERTa=0.269 | CoT=0.5 | α=0.742 | Fused=0.329 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: @user @user Darn, my sock joke needs fixing?... ---
#   CoT Length : 98 words
#   Entropy    : 0.384  →  Gamma: 0.477
#   RoBERTa=0.090 | CoT=0.5 | α=0.734 | Fused=0.199 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: if Christian expects Fifa to sleep in my bed with me tonight... ---
#   CoT Length : 89 words
#   Entropy    : 0.356  →  Gamma: 0.471
#   RoBERTa=0.031 | CoT=0.5 | α=0.706 | Fused=0.169 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: People who tell people with anxiety to "just stop worrying a... ---
#   CoT Length : 98 words
#   Entropy    : 0.504  →  Gamma: 0.501
#   RoBERTa=0.866 | CoT=1.0 | α=0.850 | Fused=0.886 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: Most important thing I've learned in school... ---
#   CoT Length : 89 words
#   Entropy    : 0.345  →  Gamma: 0.469
#   RoBERTa=0.910 | CoT=0.5 | α=0.695 | Fused=0.785 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet: #OrionLaunch underway - yeah! #Orion... ---
#   CoT Length : 100 words
#   Entropy    : 0.396  →  Gamma: 0.479
#   RoBERTa=0.359 | CoT=0.5 | α=0.746 | Fused=0.395 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: I love context and large ensemble Fridays!!!!! Der my most f... ---
#   CoT Length : 87 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   RoBERTa=0.904 | CoT=0.5 | α=0.685 | Fused=0.777 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: Oh boy... @user in the house. Warm up the DJ booth @user... ---
#   CoT Length : 61 words
#   Entropy    : 0.488  →  Gamma: 0.498
#   RoBERTa=0.073 | CoT=0.5 | α=0.838 | Fused=0.142 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: LIAR, i've never denied the 532 murders in Chicago in 2012 @... ---
#   CoT Length : 87 words
#   Entropy    : 0.280  →  Gamma: 0.456
#   RoBERTa=0.059 | CoT=0.5 | α=0.630 | Fused=0.222 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Always classy, never trashy and just a little sassy.... ---
#   CoT Length : 83 words
#   Entropy    : 0.321  →  Gamma: 0.464
#   RoBERTa=0.090 | CoT=0.0 | α=0.671 | Fused=0.061 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: you believe you can say something, provide no proof and its ... ---
#   CoT Length : 95 words
#   Entropy    : 0.427  →  Gamma: 0.485
#   RoBERTa=0.116 | CoT=0.5 | α=0.777 | Fused=0.202 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: @user #Not #Long To Go #Before #MainStream #Media #Pitch. #S... ---
#   CoT Length : 82 words
#   Entropy    : 0.341  →  Gamma: 0.468
#   RoBERTa=0.124 | CoT=1.0 | α=0.691 | Fused=0.394 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: @user Re: Jamie Grace has Tourette's? Thanks for sharing. I'... ---
#   CoT Length : 88 words
#   Entropy    : 0.324  →  Gamma: 0.465
#   RoBERTa=0.050 | CoT=1.0 | α=0.674 | Fused=0.360 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: @user Guess they didn't get the memo reg non-nuclear Baltic ... ---
#   CoT Length : 88 words
#   Entropy    : 0.441  →  Gamma: 0.488
#   RoBERTa=0.486 | CoT=0.5 | α=0.791 | Fused=0.489 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: Exam na jud. Merry christmas. ||#Sarcasm|#KillUsSlowly... ---
#   CoT Length : 83 words
#   Entropy    : 0.269  →  Gamma: 0.454
#   RoBERTa=0.155 | CoT=0.5 | α=0.619 | Fused=0.286 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: The definition of #IRONY would be if a 77-year-old rapper we... ---
#   CoT Length : 94 words
#   Entropy    : 0.312  →  Gamma: 0.463
#   RoBERTa=0.815 | CoT=0.5 | α=0.662 | Fused=0.709 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: Pretty excited about how you gave up on me. File Under: #sar... ---
#   CoT Length : 84 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   RoBERTa=0.508 | CoT=0.5 | α=0.710 | Fused=0.506 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: Who told the #hipsters that #irony was a thing of the Clinto... ---
#   CoT Length : 64 words
#   Entropy    : 0.419  →  Gamma: 0.484
#   RoBERTa=0.348 | CoT=0.0 | α=0.769 | Fused=0.267 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: @user u know that. How u doing??... ---
#   CoT Length : 89 words
#   Entropy    : 0.307  →  Gamma: 0.461
#   RoBERTa=0.026 | CoT=0.5 | α=0.657 | Fused=0.189 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: @user hmm... let me think about that #sarcasm... ---
#   CoT Length : 92 words
#   Entropy    : 0.407  →  Gamma: 0.481
#   RoBERTa=0.088 | CoT=0.5 | α=0.757 | Fused=0.188 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: If you wanna look like a badass, have drama on social media ... ---
#   CoT Length : 60 words
#   Entropy    : 0.333  →  Gamma: 0.467
#   RoBERTa=0.703 | CoT=1.0 | α=0.683 | Fused=0.797 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: How dare Charles Barkley have an intelligent conversation ab... ---
#   CoT Length : 89 words
#   Entropy    : 0.284  →  Gamma: 0.457
#   RoBERTa=0.355 | CoT=0.5 | α=0.634 | Fused=0.408 | Pred=0 | True=1 | ❌
#
# --- Processing Tweet: @user I think the general rule is, if it's open all night, p... ---
#   CoT Length : 92 words
#   Entropy    : 0.329  →  Gamma: 0.466
#   RoBERTa=0.055 | CoT=0.5 | α=0.679 | Fused=0.198 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Natalie Prass - Bird of Prey: via @user... ---
#   CoT Length : 63 words
#   Entropy    : 0.476  →  Gamma: 0.495
#   RoBERTa=0.029 | CoT=0.0 | α=0.826 | Fused=0.024 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Nooooooooooo again it's on!!! #PickANewSong #CantStandIt... ---
#   CoT Length : 46 words
#   Entropy    : 0.656  →  Gamma: 0.531
#   RoBERTa=0.266 | CoT=0.5 | α=0.850 | Fused=0.301 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Being a hipster now is so mainstream. Oh, the irony. #hipste... ---
#   CoT Length : 89 words
#   Entropy    : 0.322  →  Gamma: 0.464
#   RoBERTa=0.922 | CoT=0.5 | α=0.672 | Fused=0.783 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: @user exactly and we are fighting like animals... ---
#   CoT Length : 83 words
#   Entropy    : 0.402  →  Gamma: 0.480
#   RoBERTa=0.351 | CoT=0.5 | α=0.752 | Fused=0.388 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: #TeenAnalCasting #Top Top 50 Christian Songs For 2012... ---
#   CoT Length : 94 words
#   Entropy    : 0.480  →  Gamma: 0.496
#   RoBERTa=0.111 | CoT=0.5 | α=0.830 | Fused=0.177 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: The girls on #SororitySisters thought they'd get rich and fa... ---
#   CoT Length : 89 words
#   Entropy    : 0.432  →  Gamma: 0.486
#   RoBERTa=0.865 | CoT=0.5 | α=0.782 | Fused=0.785 | Pred=1 | True=0 | ❌
#
# --- Processing Tweet: Speaking of #country #music albums, anyone else think #Sundo... ---
#   CoT Length : 96 words
#   Entropy    : 0.511  →  Gamma: 0.502
#   RoBERTa=0.045 | CoT=1.0 | α=0.850 | Fused=0.189 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: #TeenAnalCasting #Sex Sex and the City 2 Movie Casting Audit... ---
#   CoT Length : 72 words
#   Entropy    : 0.326  →  Gamma: 0.465
#   RoBERTa=0.170 | CoT=1.0 | α=0.676 | Fused=0.439 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: season 6 episode 3 carries outfit, simple & chic 👌... ---
#   CoT Length : 69 words
#   Entropy    : 0.298  →  Gamma: 0.460
#   RoBERTa=0.089 | CoT=0.0 | α=0.648 | Fused=0.057 | Pred=0 | True=0 | ✅
#
# --- Processing Tweet: Well got the truck buried today perfect way to start a rainy... ---
#   CoT Length : 6 words
#   Entropy    : 0.190  →  Gamma: 0.438
#   RoBERTa=0.566 | CoT=1.0 | α=0.550 | Fused=0.761 | Pred=1 | True=1 | ✅
#
# --- Processing Tweet: On the train and surrounded by posh people, I'm so at home! ... ---

# %% [markdown]
# Gradient Only

# %%
import torch
import pandas as pd
from IPython.display import display

CURRENT_MODE = "GRADIENT_ONLY"
NUM_SAMPLES  = 10

results_list        = []
correct_predictions = 0

print(f"🚀 Starting RDS v2 Pipeline in {CURRENT_MODE} mode...")
print(f"   Upgrades: structured verdict prompt + entropy-adaptive alpha\n")

for i in range(NUM_SAMPLES):
    sample_tweet = test_data[i]["text"]
    true_label   = test_data[i]["label"]

    # 1. Generate CoT + gradient step (no entropy in GRADIENT_ONLY)
    result_dict = generate_cot_and_analyze_v2(sample_tweet, mode=CURRENT_MODE)

    # 2. Compress CoT FIRST using the dynamic budget + critical-token protection
    #    Note: entropy=0.0 in GRADIENT_ONLY → alpha defaults to alpha_low (0.35)
    #    meaning CoT verdict gets maximum weight in this mode
    compressed_text = compress_cot_improved(
        result_dict["cot_text"],
        result_dict["gamma_dyn"],
        result_dict["critical_tokens"]
    )

    # 3. THEN classify using the COMPRESSED CoT
    prediction, p_roberta, cot_signal, alpha, p_fused = fused_classify_v2(
        sample_tweet,
        compressed_text,            # ← was result_dict["cot_text"]
        result_dict["entropy"],
        rob_tokenizer, rob_model, device
    )

    is_correct = (prediction == true_label)
    if is_correct:
        correct_predictions += 1

    print(f"  RoBERTa={p_roberta:.3f} | CoT={cot_signal:.1f} | α={alpha:.3f} "
          f"| Fused={p_fused:.3f} | Pred={prediction} | True={true_label} "
          f"| {'✅' if is_correct else '❌'}")

    results_list.append({
        "Tweet"             : sample_tweet[:35] + "...",
        "True"              : true_label,
        "Pred"              : prediction,
        "✓?"                : "✅" if is_correct else "❌",
        "RoBERTa P(ironic)" : round(p_roberta, 3),
        "CoT Verdict"       : cot_signal,
        "α (adaptive)"      : round(alpha, 3),
        "Fused P(ironic)"   : round(p_fused, 3),
        "Entropy"           : round(result_dict["entropy"], 3),
        "Gamma"             : round(result_dict["gamma_dyn"], 3),
        "Orig Len"          : len(result_dict["cot_text"].split()),
        "Comp Len"          : len(compressed_text.split()),
        "Critical Tokens"   : str(result_dict["critical_tokens"]),
    })

accuracy_pct = (correct_predictions / NUM_SAMPLES) * 100
skip_ratio   = sum(1 - r["Comp Len"]/r["Orig Len"] for r in results_list) / NUM_SAMPLES

print(f"\n{'='*64}")
print(f"🏆 RDS v2 [{CURRENT_MODE}] ACCURACY : {accuracy_pct:.1f}%  ({correct_predictions}/{NUM_SAMPLES})")
print(f"📉 Avg Token-Skip Ratio         : {skip_ratio:.1%}")
print(f"⚖️  Alpha range used             : [0.35 – 0.75] (entropy-gated)")
print(f"{'='*64}")

df = pd.DataFrame(results_list)
display(df)
